# %% [markdown]
# <a href="https://colab.research.google.com/github/Cesarcfw/Colab-Python/blob/main/Provas/AvaliacaoA1_C%C3%A9sarChaves_CC_07jun24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Nome: César Chaves Fonsêca Watanabe Maluf
#
# * RGM: 34309985
#
# * Turma: D2
#
# * Instituição: Universidade do Distrito Federal (UDF)
#
# * Curso: Ciência da Computação
#
# * Professora: Kadidja Valéria
#
# * Tema: Avalição de Jogos

# %% [markdown]
# # Avaliação A1

# %%
import pandas as pd

#Aluno: César Chaves Fonsêca Watanabe Maluf

#Criação e alimentação de listas para o dicionario
Nome = ["Red Dead Redemption2",
        "God of War: Ragnarok",
        "Grand Theft Auto V",
        "Elden Ring",
        "Horizon Zero Dawn",
        "Anthem"]
#Lista com os nomes dos jogos

Plataforma = ["PS4, XBOXONE, PC",
              "PS5, PS4",
              "PS3, PS4, PS5, XBOX360, XBOXONE, XBOXSERIESX, PC",
              "PC, PS4, PS5, XBOXONE, XBOXSERIESX",
              "PS4, PC",
              "PC, PS4, XBOXONE"]
#Lista com as plataformas em que os jogos foram lançados

Genero = ["Ação/Aventura",
          "Hack and slash",
          "Ação/Aventura, Mundo Aberto",
          "RPG de ação, Soulslike",
          "RPG de ação, Mundo Aberto",
          "Action RPG"]
#Lista com os principais generos dos jogos

Lançamento = ["26/10/2018",
              "09/11/2022",
              "17/09/2013",
              "25/02/2022",
              "28/02/2017",
              "15/02/2019"]
#Lista com as datas de lançamento inicial dos jogos

NotaUser = ["8.8",
            "8.1",
            "8.5",
            "8.0",
            "8.4",
            "4.0"]
#Lista com as notas dadas pela maioria dos usuarios

NotaCrit = ["97",
            "94",
            "97",
            "96",
            "89",
            "59"]
#Lista com as notas dadas pelos criticos

#Criação do dicionario avaliacao_games
avaliacao_games={
    'nomes' :Nome ,
    'plataformas' :Plataforma ,
    'generos' :Genero ,
    'datas' :Lançamento ,
    'nota_geral' :NotaUser ,
    'nota_especialiazada' :NotaCrit
}

#comando para criação do dataframe
games = pd.DataFrame(avaliacao_games)

#I.index para alteração dos numeros de indexação do dataframe
games.index =["1","2", "3", "4", "5", "6"]

# %% [markdown]
# ## Questões

# %% [markdown]
# ### **1)Apresente em tela (output) toda a base de dados.**

# %%
#Metodo melhor para visualização usando display
display(games)
# Out:
#                   nomes                                       plataformas  \
# 1  Red Dead Redemption2                                  PS4, XBOXONE, PC
# 2  God of War: Ragnarok                                          PS5, PS4
# 3    Grand Theft Auto V  PS3, PS4, PS5, XBOX360, XBOXONE, XBOXSERIESX, PC
# 4            Elden Ring                PC, PS4, PS5, XBOXONE, XBOXSERIESX
# 5     Horizon Zero Dawn                                           PS4, PC
# 6                Anthem                                  PC, PS4, XBOXONE
#
#                        generos       datas nota_geral nota_especialiazada
# 1                Ação/Aventura  26/10/2018        8.8                  97
# 2               Hack and slash  09/11/2022        8.1                  94
# 3  Ação/Aventura, Mundo Aberto  17/09/2013        8.5                  97
# 4       RPG de ação, Soulslike  25/02/2022        8.0                  96
# 5    RPG de ação, Mundo Aberto  28/02/2017        8.4                  89
# ...

# %%
#Metodo arcaico para implementação do
print(games)
# Out:
#                   nomes                                       plataformas  \
# 1  Red Dead Redemption2                                  PS4, XBOXONE, PC
# 2  God of War: Ragnarok                                          PS5, PS4
# 3    Grand Theft Auto V  PS3, PS4, PS5, XBOX360, XBOXONE, XBOXSERIESX, PC
# 4            Elden Ring                PC, PS4, PS5, XBOXONE, XBOXSERIESX
# 5     Horizon Zero Dawn                                           PS4, PC
# 6                Anthem                                  PC, PS4, XBOXONE
#
#                        generos       datas nota_geral nota_especialiazada
# 1                Ação/Aventura  26/10/2018        8.8                  97
# 2               Hack and slash  09/11/2022        8.1                  94
# 3  Ação/Aventura, Mundo Aberto  17/09/2013        8.5                  97
# 4       RPG de ação, Soulslike  25/02/2022        8.0                  96
# 5    RPG de ação, Mundo Aberto  28/02/2017        8.4                  89
# ...

# %% [markdown]
# ### **2)Apresente o tamanho do seu dataframe (quantas colunas x linhas).**

# %%
#Uso do print para demonstrar o shape (linha x coluna) da tabela
print(games.shape)
# Out:
# (6, 6)

# %% [markdown]
# ### **3)Acesse a linha (x) e apresente em tela todas as características do item.**

# %%
#Uso do db.Iloc para retornar uma linha e suas colunas
games.iloc[2]
# Out:
# nomes                                                Grand Theft Auto V
# plataformas            PS3, PS4, PS5, XBOX360, XBOXONE, XBOXSERIESX, PC
# generos                                     Ação/Aventura, Mundo Aberto
# datas                                                        17/09/2013
# nota_geral                                                          8.5
# nota_especialiazada                                                  97
# Name: 3, dtype: object

# %% [markdown]
# ### **4)Verifique se o dataframe está vazio.**

# %%
#Uso do Empty para verificar com true ou false se o codigo esta fazio ou não.
print(games.empty)
# Out:
# False

# %% [markdown]
# ### **5)Apresente em tela os 5 primeiros registros da base de dados.**

# %%
#Uso do comando Head para puxar os 5 primeiros itens do dataframe.
games.head()
# Out:
#                   nomes                                       plataformas  \
# 1  Red Dead Redemption2                                  PS4, XBOXONE, PC
# 2  God of War: Ragnarok                                          PS5, PS4
# 3    Grand Theft Auto V  PS3, PS4, PS5, XBOX360, XBOXONE, XBOXSERIESX, PC
# 4            Elden Ring                PC, PS4, PS5, XBOXONE, XBOXSERIESX
# 5     Horizon Zero Dawn                                           PS4, PC
#
#                        generos       datas nota_geral nota_especialiazada
# 1                Ação/Aventura  26/10/2018        8.8                  97
# 2               Hack and slash  09/11/2022        8.1                  94
# 3  Ação/Aventura, Mundo Aberto  17/09/2013        8.5                  97
# 4       RPG de ação, Soulslike  25/02/2022        8.0                  96
# 5    RPG de ação, Mundo Aberto  28/02/2017        8.4                  89

# %% [markdown]
# ### **6)Exclua um item (linha) de sua base de dados.**

# %%
games.drop(["6"])
# Out:
#                   nomes                                       plataformas  \
# 1  Red Dead Redemption2                                  PS4, XBOXONE, PC
# 2  God of War: Ragnarok                                          PS5, PS4
# 3    Grand Theft Auto V  PS3, PS4, PS5, XBOX360, XBOXONE, XBOXSERIESX, PC
# 4            Elden Ring                PC, PS4, PS5, XBOXONE, XBOXSERIESX
# 5     Horizon Zero Dawn                                           PS4, PC
#
#                        generos       datas nota_geral nota_especialiazada
# 1                Ação/Aventura  26/10/2018        8.8                  97
# 2               Hack and slash  09/11/2022        8.1                  94
# 3  Ação/Aventura, Mundo Aberto  17/09/2013        8.5                  97
# 4       RPG de ação, Soulslike  25/02/2022        8.0                  96
# 5    RPG de ação, Mundo Aberto  28/02/2017        8.4                  89

# %% [markdown]
# ### **7)Adicione um item (linha) na sua base de dados.**

# %%
#Uso do comando loc para inserir dentro do database mais uma avaliação de jogos e o index para organização no display
games.loc[len(games)]=["Baldur's Gate 3", "PC,XBOXSERIESX,PS5", "RPG Eletrônico", "03/08/2023", "8.9", "96"]
games.index =["1","2", "3", "4", "5", "6", "7"]
display(games)
# Out:
#                   nomes                                       plataformas  \
# 1  Red Dead Redemption2                                  PS4, XBOXONE, PC
# 2  God of War: Ragnarok                                          PS5, PS4
# 3    Grand Theft Auto V  PS3, PS4, PS5, XBOX360, XBOXONE, XBOXSERIESX, PC
# 4            Elden Ring                PC, PS4, PS5, XBOXONE, XBOXSERIESX
# 5     Horizon Zero Dawn                                           PS4, PC
# 6                Anthem                                  PC, PS4, XBOXONE
# 7       Baldur's Gate 3                                PC,XBOXSERIESX,PS5
#
#                        generos       datas nota_geral nota_especialiazada
# 1                Ação/Aventura  26/10/2018        8.8                  97
# 2               Hack and slash  09/11/2022        8.1                  94
# 3  Ação/Aventura, Mundo Aberto  17/09/2013        8.5                  97
# 4       RPG de ação, Soulslike  25/02/2022        8.0                  96
# ...

# %% [markdown]
# ### **8)Transponha a coluna para a linha em sua base de dados.**

# %%
games_invertido = games.transpose()
display(games_invertido)
# Out:
#                                         1                     2  \
# nomes                Red Dead Redemption2  God of War: Ragnarok
# plataformas              PS4, XBOXONE, PC              PS5, PS4
# generos                     Ação/Aventura        Hack and slash
# datas                          26/10/2018            09/11/2022
# nota_geral                            8.8                   8.1
# nota_especialiazada                    97                    94
#
#                                                                     3  \
# nomes                                              Grand Theft Auto V
# plataformas          PS3, PS4, PS5, XBOX360, XBOXONE, XBOXSERIESX, PC
# generos                                   Ação/Aventura, Mundo Aberto
# datas                                                      17/09/2013
# nota_geral                                                        8.5
# nota_especialiazada                                                97
#
# ...

# %% [markdown]
# ### **9)Apresente em tela somente a 1ª e a 2ª coluna (rótulo) da base de dados.**

# %%
#usando o comando iloc e definindo paramentros de todas as linhas e as colunas entre 0 e 2 é retornado apenas as colunas nomes e plataformas
games.iloc[:,0:2]
# Out:
#                   nomes                                       plataformas
# 1  Red Dead Redemption2                                  PS4, XBOXONE, PC
# 2  God of War: Ragnarok                                          PS5, PS4
# 3    Grand Theft Auto V  PS3, PS4, PS5, XBOX360, XBOXONE, XBOXSERIESX, PC
# 4            Elden Ring                PC, PS4, PS5, XBOXONE, XBOXSERIESX
# 5     Horizon Zero Dawn                                           PS4, PC
# 6                Anthem                                  PC, PS4, XBOXONE
# 7       Baldur's Gate 3                                PC,XBOXSERIESX,PS5

# %% [markdown]
# ### **10)Informe como foi desenvolvido o Projeto.**

# %% [markdown]
# Usando as aulas, documentos e livros disponibilizados foi decidido que o dataframe seria feito sobre Avaliação de Jogos por ter bastante dados, um bom conteudo para o projeto e por estar presente no meu hobby de jogar e fazer lives, definido que o dataframe inicial seria composto por 6 linhas e 6 colunas utilizei 5 dados bons e um dado ruim para alimentação do dataframe.
#
# Usando o comando de display a tabela é mostrada ao usuario e ao longo das perguntas foi requisitado dados especificos, exclusão de linhas e adição de linhas envolvendo pesquisa e analise para implementação dos comandos certos para o devido funcionamento.
#
# Os livros e documentos foram usados para entender e usar como referencia para correta implementação do codigo e seu funcionamento para melhor desempenho, o uso dos comandos iloc, loc, transpose, head, drop, empty e shape foram um desafio para se entender e fazer funcionar corretamente dentro de todo o dataframe.

# %% [markdown]
# # Metadados

# %% [markdown]
# Livros/documentos:
#
# *  Gonçalves, Eduardo Corrêa, Ciência de dados (data science), Casa do Código, 2022.
#
# * Carvalho, Thiago Leite, Estrutura de dados: Domine as práticas essenciais em C, Java, C#, Python e JavaScript, Casa do codigo, 2024.
#
# * Documentos disponibilizados pela professora no blackboard
#
# * Biblioteca de informaçoes pandas: https://panda.ime.usp.br/panda/static/cc110/index.html
#
# * Curso Intensivo de Python: Uma introdução prática e baseada em projetos à programação, Eric matthes, link: https://edisciplinas.usp.br/pluginfile.php/6585696/mod_resource/content/1/Eric%20Matthes%20-%20Curso%20Intensivo%20de%20Python-Novatec%20%282016%29.pdf

# %% [markdown]
# Dados das criticas:
#
# *   https://www.metacritic.com/game/horizon-zero-dawn/
# *   https://www.metacritic.com/game/elden-ring/
# *   https://www.metacritic.com/game/grand-theft-auto-v/
# *   https://www.metacritic.com/game/anthem/
# *   https://www.metacritic.com/game/god-of-war-ragnarok/
# *   https://www.metacritic.com/game/red-dead-redemption-2/
# *   https://www.metacritic.com/game/baldurs-gate-3/
